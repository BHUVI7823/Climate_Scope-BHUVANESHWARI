# %%
from google.colab import drive
drive.mount('/content/drive')

DATA_PATH = '/content/drive/MyDrive/datasets/GlobalWeatherRepository.csv'
CLEANED_PATH = '/content/drive/MyDrive/datasets/GlobalWeatherRepository_cleaned.csv'


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_columns', 120)
pd.set_option('display.max_rows', 100)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(DATA_PATH)

print("shape:", df.shape)
display(df.head())
display(df.tail())
df.info()
display(df.describe(include='all').transpose())
# Out:
# shape: (100359, 41)
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 0                    79.8  Partly Cloudy       8.3      13.3          338
# 1                    66.2  Partly cloudy       6.9      11.2          320
# 2                    73.4          Sunny       9.4      15.1          280
# 3                    43.3  Light drizzle       7.4      11.9          215
# 4                    78.8  Partly cloudy       8.1      13.0          150
#
#   wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# 0            NNW       1012.0        29.89        0.0       0.00        24
# 1             NW       1012.0        29.88        0.1       0.00        94
# 2              W       1011.0        29.85        0.0       0.00        29
# 3             SW       1007.0        29.75        0.3       0.01        61
# 4            SSE       1011.0        29.85        0.0       0.00        89
#
#    cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 0     30                25.3                   77.5           10.0
# 1     75                19.0                   66.2           10.0
# 2      0                24.6                   76.4           10.0
# 3    100                 3.8                   38.9            2.0
# 4     50                28.7                   83.6           10.0
#
#    visibility_miles  uv_index  gust_mph  gust_kph  \
# 0               6.0       7.0       9.5      15.3
# 1               6.0       5.0      11.4      18.4
# 2               6.0       5.0      13.9      22.3
# 3               1.0       2.0       8.5      13.7
# 4               6.0       8.0      12.5      20.2
#
#    air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0                        277.0              103.0
# 1                        193.6               97.3
# 2                        540.7               12.2
# 3                        170.2               64.4
# 4                       2964.0               19.0
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 0                           1.1                          0.2
# 1                           0.9                          0.1
# 2                          65.1                         13.4
# 3                           1.6                          0.2
# 4                          72.7                         31.5
#
#    air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0                8.4              26.6                         1
# 1                1.1               2.0                         1
# 2               10.4              18.4                         1
# 3                0.7               0.9                         1
# 4              183.4             262.3                         5
#
#    air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 0                           1  04:50 AM  06:50 PM  12:12 PM  01:11 AM
# 1                           1  05:21 AM  07:54 PM  12:58 PM  02:14 AM
# 2                           1  05:40 AM  07:50 PM  01:15 PM  02:14 AM
# 3                           1  06:31 AM  09:11 PM  02:12 PM  03:31 AM
# 4                          10  06:12 AM  05:55 PM  01:17 PM  12:38 AM
#
#        moon_phase  moon_illumination
# 0  Waxing Gibbous                 55
# 1  Waxing Gibbous                 55
# 2  Waxing Gibbous                 55
# 3  Waxing Gibbous                 55
# 4  Waxing Gibbous                 55
#           country location_name  latitude  longitude         timezone  \
# 100354  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 100355    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 100356      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 100357     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 100358   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 100354          1760430600  2025-10-14 04:30                 26.3
# 100355          1760429700  2025-10-14 15:15                 28.3
# 100356          1760429700  2025-10-14 11:15                 19.0
# 100357          1760429700  2025-10-14 10:15                 30.1
# 100358          1760429700  2025-10-14 10:15                 27.3
#
#         temperature_fahrenheit condition_text  wind_mph  wind_kph  \
# 100354                    79.3  Partly cloudy       2.2       3.6
# 100355                    82.9  Moderate rain       8.1      13.0
# 100356                    66.3          Sunny       5.1       8.3
# 100357                    86.2          Sunny      11.9      19.1
# 100358                    81.1          Sunny       8.5      13.7
#
#         wind_degree wind_direction  pressure_mb  pressure_in  precip_mm  \
# 100354          175              S       1009.0        29.80       0.00
# 100355          127             SE       1010.0        29.83       0.43
# 100356            4              N       1018.0        30.06       0.00
# 100357           78            ENE       1013.0        29.92       0.00
# 100358           66            ENE       1016.0        29.99       0.00
#
#         precip_in  humidity  cloud  feels_like_celsius  feels_like_fahrenheit  \
# 100354       0.00        79     50                30.5                   86.9
# 100355       0.02        84     75                31.4                   88.5
# 100356       0.00        19      0                19.0                   66.3
# 100357       0.00        25      8                28.5                   83.3
# 100358       0.00        32     17                26.5                   79.7
#
#         visibility_km  visibility_miles  uv_index  gust_mph  gust_kph  \
# 100354           10.0               6.0       0.0       3.3       5.3
# 100355           10.0               6.0       3.3      13.0      21.0
# 100356           10.0               6.0      11.0       5.9       9.5
# 100357           10.0               6.0       7.6      13.6      22.0
# 100358           10.0               6.0       7.6       9.8      15.7
#
#         air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 100354                      1125.85               60.0
# 100355                       577.85               34.0
# 100356                       128.85               94.0
# 100357                       188.85               95.0
# 100358                       256.85              117.0
#
#         air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 100354                         12.55                         4.65
# 100355                         23.25                        18.95
# 100356                          1.65                         4.45
# 100357                          1.45                         1.85
# 100358                          2.55                         1.65
#
#         air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 100354              13.45             14.85                         1
# 100355              22.55             22.65                         2
# 100356              12.65             30.75                         1
# 100357              15.45             15.95                         1
# 100358              24.15             24.95                         2
#
#         air_quality_gb-defra-index   sunrise    sunset     moonrise   moonset  \
# 100354                           2  06:16 AM  06:10 PM     12:34 AM  01:39 PM
# 100355                           2  05:52 AM  05:34 PM  No moonrise  01:06 PM
# 100356                           2  05:55 AM  05:44 PM  No moonrise  01:09 PM
# 100357                           2  05:41 AM  06:06 PM     12:51 AM  12:16 PM
# 100358                           3  05:28 AM  05:56 PM     12:44 AM  12:00 PM
#
#              moon_phase  moon_illumination
# 100354  Waning Crescent                 46
# 100355     Last Quarter                 51
# 100356  Waning Crescent                 49
# 100357  Waning Crescent                 48
# 100358  Waning Crescent                 48
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100359 entries, 0 to 100358
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       100359 non-null  object
#  1   location_name                 100359 non-null  object
#  2   latitude                      100359 non-null  float64
#  3   longitude                     100359 non-null  float64
#  4   timezone                      100359 non-null  object
#  5   last_updated_epoch            100359 non-null  int64
#  6   last_updated                  100359 non-null  object
#  7   temperature_celsius           100359 non-null  float64
#  8   temperature_fahrenheit        100359 non-null  float64
#  9   condition_text                100359 non-null  object
#  10  wind_mph                      100359 non-null  float64
#  11  wind_kph                      100359 non-null  float64
#  12  wind_degree                   100359 non-null  int64
#  13  wind_direction                100359 non-null  object
#  14  pressure_mb                   100359 non-null  float64
#  15  pressure_in                   100359 non-null  float64
#  16  precip_mm                     100359 non-null  float64
#  17  precip_in                     100359 non-null  float64
#  18  humidity                      100359 non-null  int64
#  19  cloud                         100359 non-null  int64
#  20  feels_like_celsius            100359 non-null  float64
#  21  feels_like_fahrenheit         100359 non-null  float64
#  22  visibility_km                 100359 non-null  float64
#  23  visibility_miles              100359 non-null  float64
#  24  uv_index                      100359 non-null  float64
#  25  gust_mph                      100359 non-null  float64
#  26  gust_kph                      100359 non-null  float64
#  27  air_quality_Carbon_Monoxide   100359 non-null  float64
#  28  air_quality_Ozone             100359 non-null  float64
#  29  air_quality_Nitrogen_dioxide  100359 non-null  float64
#  30  air_quality_Sulphur_dioxide   100359 non-null  float64
#  31  air_quality_PM2.5             100359 non-null  float64
#  32  air_quality_PM10              100359 non-null  float64
#  33  air_quality_us-epa-index      100359 non-null  int64
#  34  air_quality_gb-defra-index    100359 non-null  int64
#  35  sunrise                       100359 non-null  object
#  36  sunset                        100359 non-null  object
#  37  moonrise                      100359 non-null  object
#  38  moonset                       100359 non-null  object
#  39  moon_phase                    100359 non-null  object
#  40  moon_illumination             100359 non-null  int64
# dtypes: float64(23), int64(7), object(11)
# memory usage: 31.4+ MB
#                                  count unique               top   freq  \
# country                         100359    211          Bulgaria   1114
# location_name                   100359    254             Kabul    516
# latitude                      100359.0    NaN               NaN    NaN
# longitude                     100359.0    NaN               NaN    NaN
# timezone                        100359    197      Asia/Bangkok   1956
# last_updated_epoch            100359.0    NaN               NaN    NaN
# last_updated                    100359  17044  2025-04-14 11:30     44
# temperature_celsius           100359.0    NaN               NaN    NaN
# temperature_fahrenheit        100359.0    NaN               NaN    NaN
# condition_text                  100359     47     Partly cloudy  31148
# wind_mph                      100359.0    NaN               NaN    NaN
# wind_kph                      100359.0    NaN               NaN    NaN
# wind_degree                   100359.0    NaN               NaN    NaN
# wind_direction                  100359     16                 E   9483
# pressure_mb                   100359.0    NaN               NaN    NaN
# pressure_in                   100359.0    NaN               NaN    NaN
# precip_mm                     100359.0    NaN               NaN    NaN
# precip_in                     100359.0    NaN               NaN    NaN
# humidity                      100359.0    NaN               NaN    NaN
# cloud                         100359.0    NaN               NaN    NaN
# feels_like_celsius            100359.0    NaN               NaN    NaN
# feels_like_fahrenheit         100359.0    NaN               NaN    NaN
# visibility_km                 100359.0    NaN               NaN    NaN
# visibility_miles              100359.0    NaN               NaN    NaN
# uv_index                      100359.0    NaN               NaN    NaN
# gust_mph                      100359.0    NaN               NaN    NaN
# gust_kph                      100359.0    NaN               NaN    NaN
# air_quality_Carbon_Monoxide   100359.0    NaN               NaN    NaN
# air_quality_Ozone             100359.0    NaN               NaN    NaN
# air_quality_Nitrogen_dioxide  100359.0    NaN               NaN    NaN
# air_quality_Sulphur_dioxide   100359.0    NaN               NaN    NaN
# air_quality_PM2.5             100359.0    NaN               NaN    NaN
# air_quality_PM10              100359.0    NaN               NaN    NaN
# air_quality_us-epa-index      100359.0    NaN               NaN    NaN
# air_quality_gb-defra-index    100359.0    NaN               NaN    NaN
# sunrise                         100359    458          05:56 AM   1133
# sunset                          100359    544          06:02 PM    969
# moonrise                        100359   1441       No moonrise   3477
# moonset                         100359   1441        No moonset   3302
# moon_phase                      100359      8    Waxing Gibbous  22537
# moon_illumination             100359.0    NaN               NaN    NaN
#
#                                            mean              std  \
# country                                     NaN              NaN
# location_name                               NaN              NaN
# latitude                              19.153047        24.453078
# longitude                             22.092539        65.814675
# timezone                                    NaN              NaN
# last_updated_epoch            1738190870.594565  12895175.154301
# last_updated                                NaN              NaN
# temperature_celsius                    22.73908         8.864877
# temperature_fahrenheit                72.932103        15.956594
# condition_text                              NaN              NaN
# wind_mph                               8.213591         7.809938
# wind_kph                              13.221849        12.566422
# wind_degree                          170.887384       102.744776
# wind_direction                              NaN              NaN
# pressure_mb                         1014.010323         11.27178
# pressure_in                           29.943062         0.332808
# precip_mm                              0.141158         0.600455
# precip_in                              0.005362         0.023726
# humidity                              64.370948        24.166315
# cloud                                  39.40665        33.777475
# feels_like_celsius                    23.784147        10.578924
# feels_like_fahrenheit                 74.804988        19.040253
# visibility_km                          9.639145         2.517265
# visibility_miles                       5.705228         1.565043
# uv_index                               3.842471         3.617052
# gust_mph                              11.483676         9.055984
# gust_kph                              18.483206        14.574255
# air_quality_Carbon_Monoxide           511.38402       836.236094
# air_quality_Ozone                     62.328591        32.095511
# air_quality_Nitrogen_dioxide          15.735215        25.854226
# air_quality_Sulphur_dioxide           11.156465        40.278055
# air_quality_PM2.5                      25.87273        40.404493
# air_quality_PM10                      53.006248       162.333121
# air_quality_us-epa-index               1.750854         0.976948
# air_quality_gb-defra-index             2.737393         2.552285
# sunrise                                     NaN              NaN
# sunset                                      NaN              NaN
# moonrise                                    NaN              NaN
# moonset                                     NaN              NaN
# moon_phase                                  NaN              NaN
# moon_illumination                     50.531801        35.035475
#
#                                        min           25%           50%  \
# country                                NaN           NaN           NaN
# location_name                          NaN           NaN           NaN
# latitude                             -41.3          3.75         17.25
# longitude                           -175.2       -6.8361       23.3167
# timezone                               NaN           NaN           NaN
# last_updated_epoch            1715849100.0  1727084700.0  1738232100.0
# last_updated                           NaN           NaN           NaN
# temperature_celsius                  -24.9          18.1          24.8
# temperature_fahrenheit               -12.8          64.6          76.7
# condition_text                         NaN           NaN           NaN
# wind_mph                               2.2           4.0           6.9
# wind_kph                               3.6           6.5          11.2
# wind_degree                            1.0          83.0         165.0
# wind_direction                         NaN           NaN           NaN
# pressure_mb                          947.0        1010.0        1013.0
# pressure_in                          27.96         29.83         29.92
# precip_mm                              0.0           0.0           0.0
# precip_in                              0.0           0.0           0.0
# humidity                               2.0          47.0          69.0
# cloud                                  0.0           0.0          26.0
# feels_like_celsius                   -35.6          18.1          25.9
# feels_like_fahrenheit                -32.1          64.6          78.7
# visibility_km                          0.0          10.0          10.0
# visibility_miles                       0.0           6.0           6.0
# uv_index                               0.0           0.5           3.0
# gust_mph                               2.2           6.5           9.8
# gust_kph                               3.6          10.4          15.7
# air_quality_Carbon_Monoxide        -9999.0         233.7        323.75
# air_quality_Ozone                      0.0          42.0          59.0
# air_quality_Nitrogen_dioxide           0.0           1.3         4.995
# air_quality_Sulphur_dioxide        -9999.0           0.9         2.405
# air_quality_PM2.5                    0.168           7.4        14.985
# air_quality_PM10                  -1848.15         10.73         21.83
# air_quality_us-epa-index               1.0           1.0           1.0
# air_quality_gb-defra-index             1.0           1.0           2.0
# sunrise                                NaN           NaN           NaN
# sunset                                 NaN           NaN           NaN
# moonrise                               NaN           NaN           NaN
# moonset                                NaN           NaN           NaN
# moon_phase                             NaN           NaN           NaN
# moon_illumination                      0.0          16.0          51.0
#
#                                        75%           max
# country                                NaN           NaN
# location_name                          NaN           NaN
# latitude                              40.4         64.15
# longitude                            50.58        179.22
# timezone                               NaN           NaN
# last_updated_epoch            1749372300.0  1760430600.0
# last_updated                           NaN           NaN
# temperature_celsius                   28.3          49.2
# temperature_fahrenheit                82.9         120.6
# condition_text                         NaN           NaN
# wind_mph                              11.2        1841.2
# wind_kph                              18.0        2963.2
# wind_degree                          256.0         360.0
# wind_direction                         NaN           NaN
# pressure_mb                         1018.0        3006.0
# pressure_in                          30.05         88.77
# precip_mm                             0.03         42.24
# precip_in                              0.0          1.66
# humidity                              84.0         100.0
# cloud                                 75.0         100.0
# feels_like_celsius                    30.7          51.2
# feels_like_fahrenheit                 87.3         124.2
# visibility_km                         10.0          32.0
# visibility_miles                       6.0          19.0
# uv_index                               6.8          16.3
# gust_mph                              15.2        1845.7
# gust_kph                              24.4        2970.4
# air_quality_Carbon_Monoxide          503.2     38879.398
# air_quality_Ozone                     79.0         480.7
# air_quality_Nitrogen_dioxide        17.945         427.7
# air_quality_Sulphur_dioxide          9.065        521.33
# air_quality_PM2.5                     29.6        1614.1
# air_quality_PM10                      45.3       6037.29
# air_quality_us-epa-index               2.0           6.0
# air_quality_gb-defra-index             3.0          10.0
# sunrise                                NaN           NaN
# sunset                                 NaN           NaN
# moonrise                               NaN           NaN
# moonset                                NaN           NaN
# moon_phase                             NaN           NaN
# moon_illumination                     85.0         100.0

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing_percent = (df.isnull().mean()*100).round(2).sort_values(ascending=False)
pd.concat([missing, missing_percent], axis=1, keys=['missing_count','missing_pct']).head(50)

print("duplicate rows (exact):", df.duplicated().sum())

for col in ['country','location_name'][:5]:
    if col in df.columns:
        print(f"--- {col} ---")
        print(df[col].value_counts(dropna=False).head(10))
# Out:
# duplicate rows (exact): 0
# --- country ---
# country
# Bulgaria      1114
# Indonesia     1033
# Iran          1030
# Sudan         1030
# Thailand      1029
# Turkey        1029
# Bolivia       1023
# Belgium       1008
# Madagascar     974
# Vietnam        927
# Name: count, dtype: int64
# --- location_name ---
# location_name
# Kabul               516
# Tirana              516
# Andorra La Vella    516
# Luanda              516
# Manama              516
# Yerevan             516
# Gaborone            516
# Bujumbura           516
# Sarajevo            516
# Praia               516
# Name: count, dtype: int64

# %%
df.dtypes

categorical_cols = df.select_dtypes(include=['object','category']).columns.tolist()
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print("Categorical:", len(categorical_cols), categorical_cols[:20])
print("Numeric:", len(numeric_cols), numeric_cols[:40])
# Out:
# Categorical: 11 ['country', 'location_name', 'timezone', 'last_updated', 'condition_text', 'wind_direction', 'sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase']
# Numeric: 30 ['latitude', 'longitude', 'last_updated_epoch', 'temperature_celsius', 'temperature_fahrenheit', 'wind_mph', 'wind_kph', 'wind_degree', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km', 'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide', 'air_quality_Ozone', 'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'moon_illumination']

# %%
date_candidates = [c for c in df.columns if any(k in c.lower() for k in ['date','time','timestamp','last_updated','datetime'])]
date_candidates

for c in date_candidates:
    try:
        df[c] = pd.to_datetime(df[c], errors='coerce', infer_datetime_format=True)
        print(c, "-> datetime, NaT count:", df[c].isna().sum())
    except Exception as e:
        print("failed parsing", c, e)

if 'timezone' in df.columns:
    df['timezone'] = df['timezone'].astype('string')

for c in numeric_cols:
    df[c] = pd.to_numeric(df[c], errors='coerce')

numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(include=['object','string','category']).columns.tolist()
# Out:
# /tmp/ipython-input-4228551193.py:8: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df[c] = pd.to_datetime(df[c], errors='coerce', infer_datetime_format=True)
# /tmp/ipython-input-4228551193.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[c] = pd.to_datetime(df[c], errors='coerce', infer_datetime_format=True)
# /tmp/ipython-input-4228551193.py:8: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df[c] = pd.to_datetime(df[c], errors='coerce', infer_datetime_format=True)
# /tmp/ipython-input-4228551193.py:8: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df[c] = pd.to_datetime(df[c], errors='coerce', infer_datetime_format=True)
# timezone -> datetime, NaT count: 100359
# last_updated_epoch -> datetime, NaT count: 0
# last_updated -> datetime, NaT count: 0

# %%
temp_cols = [c for c in df.columns if 'temp' in c.lower() or 'temperature' in c.lower()]
temp_cols

def convert_f_to_c(series):
    return (series - 32) * 5.0/9.0

for c in temp_cols:
    s = df[c].dropna()
    if s.empty:
        print(c, "no numeric data")
        continue
    max_val = s.max()
    mean_val = s.mean()
    decision = "assume_C"
    if max_val > 60 or mean_val > 40:
        df[c + '_orig_f'] = df[c]   # preserve original
        df[c] = convert_f_to_c(df[c])
        decision = "converted_F_to_C"
    print(c, "max:", max_val, "mean:", mean_val, "=>", decision)
# Out:
# temperature_celsius max: 49.2 mean: 22.73907970386313 => assume_C
# temperature_fahrenheit max: 120.6 mean: 72.93210275112347 => converted_F_to_C

# %%
display(df[numeric_cols].describe().transpose())

stats_df = df[numeric_cols].agg(['mean','median','std','min','max','skew','kurt']).transpose()
display(stats_df)

import math
cols_to_plot = numeric_cols
n = len(cols_to_plot)
cols_per_row = 3
rows = math.ceil(n/cols_per_row)
plt.figure(figsize=(16,4*rows))
for i, col in enumerate(cols_to_plot, 1):
    plt.subplot(rows, cols_per_row, i)
    df[col].hist(bins=50)
    plt.title(col)
plt.tight_layout()
# Out:
#                                  count          mean           std  \
# latitude                      100359.0  1.915305e+01  2.445308e+01
# longitude                     100359.0  2.209254e+01  6.581468e+01
# last_updated_epoch            100359.0  1.738191e+09  1.289518e+07
# temperature_celsius           100359.0  2.273908e+01  8.864877e+00
# temperature_fahrenheit        100359.0  2.274006e+01  8.864774e+00
# wind_mph                      100359.0  8.213591e+00  7.809938e+00
# wind_kph                      100359.0  1.322185e+01  1.256642e+01
# wind_degree                   100359.0  1.708874e+02  1.027448e+02
# pressure_mb                   100359.0  1.014010e+03  1.127178e+01
# pressure_in                   100359.0  2.994306e+01  3.328079e-01
# precip_mm                     100359.0  1.411583e-01  6.004555e-01
# precip_in                     100359.0  5.362349e-03  2.372608e-02
# humidity                      100359.0  6.437095e+01  2.416631e+01
# cloud                         100359.0  3.940665e+01  3.377748e+01
# feels_like_celsius            100359.0  2.378415e+01  1.057892e+01
# feels_like_fahrenheit         100359.0  7.480499e+01  1.904025e+01
# visibility_km                 100359.0  9.639145e+00  2.517265e+00
# visibility_miles              100359.0  5.705228e+00  1.565043e+00
# uv_index                      100359.0  3.842471e+00  3.617052e+00
# gust_mph                      100359.0  1.148368e+01  9.055984e+00
# gust_kph                      100359.0  1.848321e+01  1.457426e+01
# air_quality_Carbon_Monoxide   100359.0  5.113840e+02  8.362361e+02
# air_quality_Ozone             100359.0  6.232859e+01  3.209551e+01
# air_quality_Nitrogen_dioxide  100359.0  1.573522e+01  2.585423e+01
# air_quality_Sulphur_dioxide   100359.0  1.115646e+01  4.027805e+01
# air_quality_PM2.5             100359.0  2.587273e+01  4.040449e+01
# air_quality_PM10              100359.0  5.300625e+01  1.623331e+02
# air_quality_us-epa-index      100359.0  1.750854e+00  9.769477e-01
# air_quality_gb-defra-index    100359.0  2.737393e+00  2.552285e+00
# moon_illumination             100359.0  5.053180e+01  3.503547e+01
#
#                                        min           25%           50%  \
# latitude                     -4.130000e+01  3.750000e+00  1.725000e+01
# longitude                    -1.752000e+02 -6.836100e+00  2.331670e+01
# last_updated_epoch            1.715849e+09  1.727085e+09  1.738232e+09
# temperature_celsius          -2.490000e+01  1.810000e+01  2.480000e+01
# temperature_fahrenheit       -2.488889e+01  1.811111e+01  2.483333e+01
# wind_mph                      2.200000e+00  4.000000e+00  6.900000e+00
# wind_kph                      3.600000e+00  6.500000e+00  1.120000e+01
# wind_degree                   1.000000e+00  8.300000e+01  1.650000e+02
# pressure_mb                   9.470000e+02  1.010000e+03  1.013000e+03
# pressure_in                   2.796000e+01  2.983000e+01  2.992000e+01
# precip_mm                     0.000000e+00  0.000000e+00  0.000000e+00
# precip_in                     0.000000e+00  0.000000e+00  0.000000e+00
# humidity                      2.000000e+00  4.700000e+01  6.900000e+01
# cloud                         0.000000e+00  0.000000e+00  2.600000e+01
# feels_like_celsius           -3.560000e+01  1.810000e+01  2.590000e+01
# feels_like_fahrenheit        -3.210000e+01  6.460000e+01  7.870000e+01
# visibility_km                 0.000000e+00  1.000000e+01  1.000000e+01
# visibility_miles              0.000000e+00  6.000000e+00  6.000000e+00
# uv_index                      0.000000e+00  5.000000e-01  3.000000e+00
# gust_mph                      2.200000e+00  6.500000e+00  9.800000e+00
# gust_kph                      3.600000e+00  1.040000e+01  1.570000e+01
# air_quality_Carbon_Monoxide  -9.999000e+03  2.337000e+02  3.237500e+02
# air_quality_Ozone             0.000000e+00  4.200000e+01  5.900000e+01
# air_quality_Nitrogen_dioxide  0.000000e+00  1.300000e+00  4.995000e+00
# air_quality_Sulphur_dioxide  -9.999000e+03  9.000000e-01  2.405000e+00
# air_quality_PM2.5             1.680000e-01  7.400000e+00  1.498500e+01
# air_quality_PM10             -1.848150e+03  1.073000e+01  2.183000e+01
# air_quality_us-epa-index      1.000000e+00  1.000000e+00  1.000000e+00
# air_quality_gb-defra-index    1.000000e+00  1.000000e+00  2.000000e+00
# moon_illumination             0.000000e+00  1.600000e+01  5.100000e+01
#
#                                        75%           max
# latitude                      4.040000e+01  6.415000e+01
# longitude                     5.058000e+01  1.792200e+02
# last_updated_epoch            1.749372e+09  1.760431e+09
# temperature_celsius           2.830000e+01  4.920000e+01
# temperature_fahrenheit        2.827778e+01  4.922222e+01
# wind_mph                      1.120000e+01  1.841200e+03
# wind_kph                      1.800000e+01  2.963200e+03
# wind_degree                   2.560000e+02  3.600000e+02
# pressure_mb                   1.018000e+03  3.006000e+03
# pressure_in                   3.005000e+01  8.877000e+01
# precip_mm                     3.000000e-02  4.224000e+01
# precip_in                     0.000000e+00  1.660000e+00
# humidity                      8.400000e+01  1.000000e+02
# cloud                         7.500000e+01  1.000000e+02
# feels_like_celsius            3.070000e+01  5.120000e+01
# feels_like_fahrenheit         8.730000e+01  1.242000e+02
# visibility_km                 1.000000e+01  3.200000e+01
# visibility_miles              6.000000e+00  1.900000e+01
# uv_index                      6.800000e+00  1.630000e+01
# gust_mph                      1.520000e+01  1.845700e+03
# gust_kph                      2.440000e+01  2.970400e+03
# air_quality_Carbon_Monoxide   5.032000e+02  3.887940e+04
# air_quality_Ozone             7.900000e+01  4.807000e+02
# air_quality_Nitrogen_dioxide  1.794500e+01  4.277000e+02
# air_quality_Sulphur_dioxide   9.065000e+00  5.213300e+02
# air_quality_PM2.5             2.960000e+01  1.614100e+03
# air_quality_PM10              4.530000e+01  6.037290e+03
# air_quality_us-epa-index      2.000000e+00  6.000000e+00
# air_quality_gb-defra-index    3.000000e+00  1.000000e+01
# moon_illumination             8.500000e+01  1.000000e+02
#                                       mean        median           std  \
# latitude                      1.915305e+01  1.725000e+01  2.445308e+01
# longitude                     2.209254e+01  2.331670e+01  6.581468e+01
# last_updated_epoch            1.738191e+09  1.738232e+09  1.289518e+07
# temperature_celsius           2.273908e+01  2.480000e+01  8.864877e+00
# temperature_fahrenheit        2.274006e+01  2.483333e+01  8.864774e+00
# wind_mph                      8.213591e+00  6.900000e+00  7.809938e+00
# wind_kph                      1.322185e+01  1.120000e+01  1.256642e+01
# wind_degree                   1.708874e+02  1.650000e+02  1.027448e+02
# pressure_mb                   1.014010e+03  1.013000e+03  1.127178e+01
# pressure_in                   2.994306e+01  2.992000e+01  3.328079e-01
# precip_mm                     1.411583e-01  0.000000e+00  6.004555e-01
# precip_in                     5.362349e-03  0.000000e+00  2.372608e-02
# humidity                      6.437095e+01  6.900000e+01  2.416631e+01
# cloud                         3.940665e+01  2.600000e+01  3.377748e+01
# feels_like_celsius            2.378415e+01  2.590000e+01  1.057892e+01
# feels_like_fahrenheit         7.480499e+01  7.870000e+01  1.904025e+01
# visibility_km                 9.639145e+00  1.000000e+01  2.517265e+00
# visibility_miles              5.705228e+00  6.000000e+00  1.565043e+00
# uv_index                      3.842471e+00  3.000000e+00  3.617052e+00
# gust_mph                      1.148368e+01  9.800000e+00  9.055984e+00
# gust_kph                      1.848321e+01  1.570000e+01  1.457426e+01
# air_quality_Carbon_Monoxide   5.113840e+02  3.237500e+02  8.362361e+02
# air_quality_Ozone             6.232859e+01  5.900000e+01  3.209551e+01
# air_quality_Nitrogen_dioxide  1.573522e+01  4.995000e+00  2.585423e+01
# air_quality_Sulphur_dioxide   1.115646e+01  2.405000e+00  4.027805e+01
# air_quality_PM2.5             2.587273e+01  1.498500e+01  4.040449e+01
# air_quality_PM10              5.300625e+01  2.183000e+01  1.623331e+02
# air_quality_us-epa-index      1.750854e+00  1.000000e+00  9.769477e-01
# air_quality_gb-defra-index    2.737393e+00  2.000000e+00  2.552285e+00
# moon_illumination             5.053180e+01  5.100000e+01  3.503547e+01
#
#                                        min           max        skew  \
# latitude                     -4.130000e+01  6.415000e+01   -0.305723
# longitude                    -1.752000e+02  1.792200e+02    0.003557
# last_updated_epoch            1.715849e+09  1.760431e+09   -0.008771
# temperature_celsius          -2.490000e+01  4.920000e+01   -0.789301
# temperature_fahrenheit       -2.488889e+01  4.922222e+01   -0.789248
# wind_mph                      2.200000e+00  1.841200e+03  129.359716
# wind_kph                      3.600000e+00  2.963200e+03  129.445335
# wind_degree                   1.000000e+00  3.600000e+02    0.151584
# pressure_mb                   9.470000e+02  3.006000e+03  109.532432
# pressure_in                   2.796000e+01  8.877000e+01  109.594894
# precip_mm                     0.000000e+00  4.224000e+01   18.148645
# precip_in                     0.000000e+00  1.660000e+00   17.987155
# humidity                      2.000000e+00  1.000000e+02   -0.550699
# cloud                         0.000000e+00  1.000000e+02    0.255421
# feels_like_celsius           -3.560000e+01  5.120000e+01   -0.790553
# feels_like_fahrenheit        -3.210000e+01  1.242000e+02   -0.790287
# visibility_km                 0.000000e+00  3.200000e+01    1.478234
# visibility_miles              0.000000e+00  1.900000e+01    0.927049
# uv_index                      0.000000e+00  1.630000e+01    0.700466
# gust_mph                      2.200000e+00  1.845700e+03   83.499036
# gust_kph                      3.600000e+00  2.970400e+03   83.500482
# air_quality_Carbon_Monoxide  -9.999000e+03  3.887940e+04   12.844874
# air_quality_Ozone             0.000000e+00  4.807000e+02    1.235829
# air_quality_Nitrogen_dioxide  0.000000e+00  4.277000e+02    3.064143
# air_quality_Sulphur_dioxide  -9.999000e+03  5.213300e+02 -151.767745
# air_quality_PM2.5             1.680000e-01  1.614100e+03    8.872993
# air_quality_PM10             -1.848150e+03  6.037290e+03   16.190960
# air_quality_us-epa-index      1.000000e+00  6.000000e+00    1.462160
# air_quality_gb-defra-index    1.000000e+00  1.000000e+01    1.860026
# moon_illumination             0.000000e+00  1.000000e+02   -0.030381
#
#                                       kurt
# latitude                         -0.745894
# longitude                         0.333249
# last_updated_epoch               -1.194177
# temperature_celsius               0.876880
# temperature_fahrenheit            0.876718
# wind_mph                      30237.662012
# wind_kph                      30264.271561
# wind_degree                      -1.165322
# pressure_mb                   19320.484331
# pressure_in                   19334.327061
# precip_mm                       662.133457
# precip_in                       652.393856
# humidity                         -0.644187
# cloud                            -1.339744
# feels_like_celsius                0.809411
# feels_like_fahrenheit             0.808681
# visibility_km                    15.766437
# visibility_miles                 12.659398
# uv_index                         -0.439966
# gust_mph                      16771.127139
# gust_kph                      16771.560624
# air_quality_Carbon_Monoxide     317.289739
# air_quality_Ozone                 5.476496
# air_quality_Nitrogen_dioxide     12.713532
# air_quality_Sulphur_dioxide   38018.842884
# air_quality_PM2.5               163.191520
# air_quality_PM10                381.717245
# air_quality_us-epa-index          1.976522
# air_quality_gb-defra-index        2.410202
# moon_illumination                -1.481832

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df[numeric_cols].sample(frac=0.05, random_state=1), orient='h')
# Out:
# <Axes: >

# %%
for c in categorical_cols[:6]:
    print("=== ", c, "===")
    display(df[c].value_counts(dropna=False).head(20))
# Out:
# ===  country ===
# country
# Bulgaria        1114
# Indonesia       1033
# Iran            1030
# Sudan           1030
# Thailand        1029
# Turkey          1029
# Bolivia         1023
# Belgium         1008
# Madagascar       974
# Vietnam          927
# Switzerland      536
# Russia           529
# Hungary          520
# Kenya            517
# Botswana         516
# Bahrain          516
# Andorra          516
# Fiji Islands     516
# Finland          516
# Vatican City     516
# Name: count, dtype: int64
# ===  location_name ===
# location_name
# Kabul               516
# Tirana              516
# Andorra La Vella    516
# Luanda              516
# Manama              516
# Yerevan             516
# Gaborone            516
# Bujumbura           516
# Sarajevo            516
# Praia               516
# Minsk               516
# Helsinki            516
# Moroni              516
# N'djamena           516
# Suva                516
# Malabo              516
# Tallinn             516
# Asmara              516
# Valletta            516
# Bamako              516
# Name: count, dtype: int64
# ===  timezone ===
# timezone
# <NA>    100359
# Name: count, dtype: Int64
# ===  condition_text ===
# condition_text
# Partly cloudy                             31148
# Sunny                                     31000
# Patchy rain nearby                         8331
# Partly Cloudy                              5490
# Overcast                                   4820
# Clear                                      4425
# Mist                                       3165
# Light rain                                 2992
# Light rain shower                          2412
# Cloudy                                     1002
# Fog                                         933
# Moderate or heavy rain with thunder         891
# Moderate rain                               764
# Patchy light rain with thunder              619
# Light drizzle                               447
# Patchy light drizzle                        326
# Moderate or heavy rain shower               232
# Thundery outbreaks in nearby                216
# Light snow                                  189
# Patchy light rain in area with thunder      175
# Name: count, dtype: int64
# ===  wind_direction ===
# wind_direction
# E      9483
# ENE    7908
# ESE    7016
# N      6550
# S      6214
# NNE    6177
# WSW    6176
# SW     6130
# SSW    6125
# SSE    5985
# NNW    5735
# SE     5532
# NE     5487
# W      5440
# WNW    5283
# NW     5118
# Name: count, dtype: int64
# ===  sunrise ===
# sunrise
# 05:56 AM    1133
# 05:57 AM    1128
# 05:55 AM    1120
# 05:54 AM    1090
# 06:17 AM    1053
# 05:58 AM    1032
# 06:10 AM    1030
# 05:49 AM    1016
# 06:21 AM    1013
# 06:05 AM    1000
# 06:11 AM    1000
# 05:50 AM     989
# 05:53 AM     987
# 06:23 AM     955
# 06:16 AM     951
# 06:24 AM     949
# 06:06 AM     945
# 06:07 AM     942
# 05:59 AM     932
# 06:15 AM     925
# Name: count, dtype: int64

# %%
corr = df[numeric_cols].corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)
plt.title("Correlation matrix (numeric features)")
plt.show()
pairs = [('temperature_celsius','humidity'), ('temperature_celsius','wind_kph')]  # edit as appropriate
for x,y in pairs:
    if x in df.columns and y in df.columns:
        plt.figure(figsize=(6,4))
        sns.scatterplot(data=df, x=x, y=y, alpha=0.2, s=8)
        sns.regplot(data=df.sample(n=2000, random_state=1), x=x, y=y, scatter=False, color='red')  # sample for regression line
        plt.title(f"{y} vs {x}")
        plt.show()

# %%
def iqr_outlier_bounds(s):
    Q1 = s.quantile(0.25)
    Q3 = s.quantile(0.75)
    IQR = Q3 - Q1
    return Q1 - 1.5*IQR, Q3 + 1.5*IQR

outlier_info = {}
for c in numeric_cols:
    s = df[c].dropna()
    if s.empty: continue
    low, high = iqr_outlier_bounds(s)
    out_count = ((s < low) | (s > high)).sum()
    outlier_info[c] = {'low': low, 'high': high, 'outliers': int(out_count)}
pd.DataFrame(outlier_info).T.sort_values('outliers', ascending=False).head(20)
# Out:
#                                      low         high  outliers
# visibility_km                  10.000000    10.000000   19250.0
# visibility_miles                6.000000     6.000000   19117.0
# precip_mm                      -0.045000     0.075000   19019.0
# precip_in                       0.000000     0.000000   15933.0
# air_quality_Sulphur_dioxide   -11.347500    21.312500   13546.0
# air_quality_Nitrogen_dioxide  -23.667500    42.912500   11043.0
# air_quality_gb-defra-index     -2.000000     6.000000   10785.0
# air_quality_PM10              -41.125000    97.155000   10697.0
# air_quality_Carbon_Monoxide  -170.550000   907.450000    9078.0
# air_quality_PM2.5             -25.900000    62.900000    8428.0
# air_quality_us-epa-index       -0.500000     3.500000    7904.0
# longitude                     -92.960250   136.704150    7719.0
# pressure_in                    29.500000    30.380000    4694.0
# temperature_fahrenheit          2.861111    43.527778    3298.0
# temperature_celsius             2.800000    43.600000    3287.0
# pressure_mb                   998.000000  1030.000000    3104.0
# feels_like_celsius             -0.800000    49.600000    2692.0
# feels_like_fahrenheit          30.550000   121.350000    2664.0
# gust_kph                      -10.600000    45.400000    2618.0
# gust_mph                       -6.550000    28.250000    2589.0

# %%
missing = (df.isnull().mean()*100).round(2).sort_values(ascending=False)
display(missing.head(60))

num_impute_cols = numeric_cols
for c in num_impute_cols:
    med = df[c].median()
    df[c] = df[c].fillna(med)

for c in categorical_cols:
    if df[c].isnull().any():
        mode = df[c].mode(dropna=True)
        fill_val = mode[0] if not mode.empty else 'Unknown'
        df[c] = df[c].fillna(fill_val)
# Out:
# timezone                         100.0
# country                            0.0
# location_name                      0.0
# latitude                           0.0
# longitude                          0.0
# last_updated_epoch                 0.0
# last_updated                       0.0
# temperature_celsius                0.0
# temperature_fahrenheit             0.0
# condition_text                     0.0
# wind_mph                           0.0
# wind_kph                           0.0
# wind_degree                        0.0
# wind_direction                     0.0
# pressure_mb                        0.0
# pressure_in                        0.0
# precip_mm                          0.0
# precip_in                          0.0
# humidity                           0.0
# cloud                              0.0
# feels_like_celsius                 0.0
# feels_like_fahrenheit              0.0
# visibility_km                      0.0
# visibility_miles                   0.0
# uv_index                           0.0
# gust_mph                           0.0
# gust_kph                           0.0
# air_quality_Carbon_Monoxide        0.0
# air_quality_Ozone                  0.0
# air_quality_Nitrogen_dioxide       0.0
# air_quality_Sulphur_dioxide        0.0
# air_quality_PM2.5                  0.0
# air_quality_PM10                   0.0
# air_quality_us-epa-index           0.0
# air_quality_gb-defra-index         0.0
# sunrise                            0.0
# sunset                             0.0
# moonrise                           0.0
# moonset                            0.0
# moon_phase                         0.0
# moon_illumination                  0.0
# temperature_fahrenheit_orig_f      0.0
# dtype: float64

# %%
date_col = 'last_updated'
df[date_col] = pd.to_datetime(df[date_col], errors='coerce')
df['Year'] = df[date_col].dt.year
df['Month'] = df[date_col].dt.month
df['Day'] = df[date_col].dt.day

def month_to_season(m):
    if m in [12,1,2]: return 'Winter'
    if m in [3,4,5]: return 'Spring'
    if m in [6,7,8]: return 'Summer'
    return 'Autumn'
df['Season'] = df['Month'].apply(lambda x: month_to_season(x) if not pd.isna(x) else np.nan)

if 'temperature_celsius' in df.columns:
    df['temp_bin'] = pd.cut(df['temperature_celsius'], bins=[-50,0,10,20,30,40,100], labels=['<-0','0-10','10-20','20-30','30-40','40+'])

# %%
df = df.sort_values(by=[ 'location_name', date_col ])
df['temp_7d_mean'] = df.groupby('location_name')['temperature_celsius'].transform(lambda x: x.rolling(window=7, min_periods=1).mean())

# %%
df = df.dropna(subset=['latitude','longitude'])

df = df[(df['latitude'].between(-90,90)) & (df['longitude'].between(-180,180))]

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination',
#        'temperature_fahrenheit_orig_f', 'Year', 'Month', 'Day', 'Season',
#        'temp_bin', 'temp_7d_mean', 'date_only', 'year_month'],
#       dtype='object')

# %%
date_col = 'date_only'
df[date_col] = pd.to_datetime(df[date_col])

agg_cols = {
    'temperature_celsius': ['mean', 'median', 'min', 'max', 'std'],
    'precip_mm': ['sum', 'mean', 'max'],   # fixed column name here
    'humidity': ['mean']
}

df['year_month'] = df[date_col].dt.to_period('M')

monthly = df.groupby(['year_month', 'location_name']).agg(agg_cols)
monthly.columns = ['_'.join(col) for col in monthly.columns]
monthly = monthly.reset_index()

print("Monthly Aggregation Done!")
display(monthly.head())

df['year'] = df[date_col].dt.year

yearly = df.groupby(['year', 'location_name']).agg(agg_cols)
yearly.columns = ['_'.join(col) for col in yearly.columns]
yearly = yearly.reset_index()

print("Yearly Aggregation Done!")
display(yearly.head())
# Out:
# ✅ Monthly Aggregation Done!
#   year_month      location_name  temperature_celsius_mean  \
# 0    2024-05  'S Gravenjansdijk                 16.000000
# 1    2024-05   'S Gravenstaffel                 15.562500
# 2    2024-05          Abu Dhabi                 35.352941
# 3    2024-05              Abuja                 33.323529
# 4    2024-05              Accra                 30.358824
#
#    temperature_celsius_median  temperature_celsius_min  \
# 0                        16.0                     16.0
# 1                        15.5                     13.0
# 2                        36.0                     32.0
# 3                        33.0                     29.2
# 4                        30.0                     28.0
#
#    temperature_celsius_max  temperature_celsius_std  precip_mm_sum  \
# 0                     16.0                      NaN           0.29
# 1                     19.0                 1.504161           3.02
# 2                     39.0                 2.206274           0.00
# 3                     39.4                 2.465139           0.00
# 4                     33.0                 1.388821           1.78
#
#    precip_mm_mean  precip_mm_max  humidity_mean
# 0        0.290000           0.29      82.000000
# 1        0.188750           0.87      80.500000
# 2        0.000000           0.00      39.235294
# 3        0.000000           0.00      54.588235
# 4        0.104706           1.54      72.176471
# ✅ Yearly Aggregation Done!
#    year      location_name  temperature_celsius_mean  \
# 0  2024  'S Gravenjansdijk                 15.659799
# 1  2024   'S Gravenjansdyk                 16.341667
# 2  2024   'S Gravenstaffel                 15.562500
# 3  2024           -Kingdom                 29.700000
# 4  2024          Abu Dhabi                 33.939738
#
#    temperature_celsius_median  temperature_celsius_min  \
# 0                       16.10                      1.1
# 1                       17.05                     12.1
# 2                       15.50                     13.0
# 3                       29.70                     29.7
# 4                       34.90                     20.4
#
#    temperature_celsius_max  temperature_celsius_std  precip_mm_sum  \
# 0                     32.2                 7.121655          23.15
# 1                     18.6                 2.091741           1.93
# 2                     19.0                 1.504161           3.02
# 3                     29.7                      NaN           0.00
# 4                     44.1                 5.505232           0.09
#
#    precip_mm_mean  precip_mm_max  humidity_mean
# 0        0.116332           1.94      73.773869
# 1        0.160833           1.70      67.583333
# 2        0.188750           0.87      80.500000
# 3        0.000000           0.00      24.000000
# 4        0.000393           0.05      49.318777

# %%
# Save the cleaned full dataset
df.to_csv(CLEANED_PATH, index=False)
print("Saved cleaned dataset to:", CLEANED_PATH)

# Save summary aggregates if needed
monthly_path = '/content/drive/MyDrive/datasets/GlobalWeatherRepository_monthly.csv'
monthly.to_csv(monthly_path, index=False)
print("Saved monthly aggregates to:", monthly_path)
# Out:
# Saved cleaned dataset to: /content/drive/MyDrive/datasets/GlobalWeatherRepository_cleaned.csv
# Saved monthly aggregates to: /content/drive/MyDrive/datasets/GlobalWeatherRepository_monthly.csv

# %%
monthly = df.groupby(['year_month', 'location_name']).agg(agg_cols)

# %%
monthly.columns
# Out:
# MultiIndex([('temperature_celsius',   'mean'),
#             ('temperature_celsius', 'median'),
#             ('temperature_celsius',    'min'),
#             ('temperature_celsius',    'max'),
#             ('temperature_celsius',    'std'),
#             (          'precip_mm',    'sum'),
#             (          'precip_mm',   'mean'),
#             (          'precip_mm',    'max'),
#             (           'humidity',   'mean')],
#            )

# %%
# Reset index to bring 'year_month' and 'location_name' back as columns
monthly = monthly.reset_index()

# Flatten MultiIndex columns into single level
monthly.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in monthly.columns]

# Show the fixed columns
print(monthly.columns)
monthly.head()
# Out:
# Index(['year_month_', 'location_name_', 'temperature_celsius_mean',
#        'temperature_celsius_median', 'temperature_celsius_min',
#        'temperature_celsius_max', 'temperature_celsius_std', 'precip_mm_sum',
#        'precip_mm_mean', 'precip_mm_max', 'humidity_mean'],
#       dtype='object')
#   year_month_     location_name_  temperature_celsius_mean  \
# 0     2024-05  'S Gravenjansdijk                 16.000000
# 1     2024-05   'S Gravenstaffel                 15.562500
# 2     2024-05          Abu Dhabi                 35.352941
# 3     2024-05              Abuja                 33.323529
# 4     2024-05              Accra                 30.358824
#
#    temperature_celsius_median  temperature_celsius_min  \
# 0                        16.0                     16.0
# 1                        15.5                     13.0
# 2                        36.0                     32.0
# 3                        33.0                     29.2
# 4                        30.0                     28.0
#
#    temperature_celsius_max  temperature_celsius_std  precip_mm_sum  \
# 0                     16.0                      NaN           0.29
# 1                     19.0                 1.504161           3.02
# 2                     39.0                 2.206274           0.00
# 3                     39.4                 2.465139           0.00
# 4                     33.0                 1.388821           1.78
#
#    precip_mm_mean  precip_mm_max  humidity_mean
# 0        0.290000           0.29      82.000000
# 1        0.188750           0.87      80.500000
# 2        0.000000           0.00      39.235294
# 3        0.000000           0.00      54.588235
# 4        0.104706           1.54      72.176471

# %%
for c in categorical_cols:
    if df[c].isna().sum() > 0:
        mode = df[c].mode()[0]
        df[c] = df[c].fillna(mode)

# %%
df = df.drop_duplicates()

# %%
if 'last_updated' in df.columns:
    df['Year'] = df['last_updated'].dt.year
    df['Month'] = df['last_updated'].dt.month
    df['Season'] = df['Month'].map({12:'Winter',1:'Winter',2:'Winter',
                                    3:'Spring',4:'Spring',5:'Spring',
                                    6:'Summer',7:'Summer',8:'Summer',
                                    9:'Autumn',10:'Autumn',11:'Autumn'})

# %%
df = df[(df['humidity'].between(0,100)) & (df['temperature_celsius'].between(-50,60))]

# %%
monthly_avg = df.groupby(['country','Year','Month'])['temperature_celsius'].mean().reset_index()

# %%
df.to_csv('/content/drive/MyDrive/datasets/GlobalWeatherRepository_cleaned.csv', index=False)
print("Cleaned dataset saved successfully!")
# Out:
# ✅ Cleaned dataset saved successfully!

# %%
# 1️⃣ Remove duplicate rows
print("Before removing duplicates:", df.shape)
df = df.drop_duplicates()
print("After removing duplicates:", df.shape)

# 2️⃣ Handle missing values (complete categorical imputation)
for c in categorical_cols:
    if df[c].isna().sum() > 0:
        mode = df[c].mode()[0]
        df[c] = df[c].fillna(mode)
print("✅ Missing values handled.")

# 3️⃣ Create new time-based features (if date column available)
if 'last_updated' in df.columns:
    df['Year'] = df['last_updated'].dt.year
    df['Month'] = df['last_updated'].dt.month
    df['Season'] = df['Month'].map({
        12: 'Winter', 1: 'Winter', 2: 'Winter',
        3: 'Spring', 4: 'Spring', 5: 'Spring',
        6: 'Summer', 7: 'Summer', 8: 'Summer',
        9: 'Autumn', 10: 'Autumn', 11: 'Autumn'
    })
    print("✅ Added Year, Month, and Season columns.")


# 4️⃣ Filter unwanted / noisy data
# Example thresholds — adjust depending on your dataset
if 'humidity' in df.columns and 'temperature_celsius' in df.columns:
    df = df[(df['humidity'].between(0, 100)) &
            (df['temperature_celsius'].between(-50, 60))]
    print("✅ Filtered unrealistic humidity/temperature values.")


# 5️⃣ Aggregate data if needed (e.g., monthly mean per country)
if {'country', 'Year', 'Month', 'temperature_celsius'}.issubset(df.columns):
    monthly_avg = (
        df.groupby(['country', 'Year', 'Month'])['temperature_celsius']
        .mean()
        .reset_index()
        .rename(columns={'temperature_celsius': 'avg_temp_c'})
    )
    print("✅ Created monthly average temperature table.")
else:
    monthly_avg = df.copy()  # fallback


# 6️⃣ Save cleaned dataset for visualization
clean_path = '/content/drive/MyDrive/datasets/GlobalWeatherRepository_cleaned.csv'
df.to_csv(clean_path, index=False)
print(f"✅ Cleaned dataset saved successfully at: {clean_path}")

# Optional: also save aggregated dataset
monthly_avg.to_csv('/content/drive/MyDrive/datasets/GlobalWeatherRepository_monthly_avg.csv', index=False)
print("✅ Monthly aggregated dataset saved successfully!")

# Final check
print("Final shape:", df.shape)
df.head()
# Out:
# Before removing duplicates: (100359, 51)
# After removing duplicates: (100359, 51)
# ✅ Missing values handled.
# ✅ Added Year, Month, and Season columns.
# ✅ Filtered unrealistic humidity/temperature values.
# ✅ Created monthly average temperature table.
# ✅ Cleaned dataset saved successfully at: /content/drive/MyDrive/datasets/GlobalWeatherRepository_cleaned.csv
# ✅ Monthly aggregated dataset saved successfully!
# Final shape: (100359, 51)
#       country      location_name  latitude  longitude timezone  \
# 3265  Belgium  'S Gravenjansdijk     51.25       3.63  Unknown
# 3460  Belgium  'S Gravenjansdijk     51.25       3.63  Unknown
# 4045  Belgium  'S Gravenjansdijk     51.25       3.63  Unknown
# 4240  Belgium  'S Gravenjansdijk     51.25       3.63  Unknown
# 5408  Belgium  'S Gravenjansdijk     51.25       3.63  Unknown
#
#       last_updated_epoch        last_updated  temperature_celsius  \
# 3265          1717164900 2024-05-31 16:15:00                 16.0
# 3460          1717252200 2024-06-01 16:30:00                 16.0
# 4045          1717510500 2024-06-04 16:15:00                 18.0
# 4240          1717596900 2024-06-05 16:15:00                 15.0
# 5408          1718115300 2024-06-11 16:15:00                 15.2
#
#       temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 3265               16.000000  Moderate rain      17.4      28.1           20
# 3460               16.000000       Overcast       9.4      15.1          330
# 4045               18.000000  Partly cloudy      16.1      25.9          270
# 4240               15.000000  Partly cloudy       6.9      11.2          330
# 5408               15.222222  Partly cloudy      15.0      24.1          280
#
#      wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# 3265            NNE       1014.0        29.94       0.29       0.01        82
# 3460            NNW       1019.0        30.09       0.01       0.00        88
# 4045              W       1011.0        29.85       0.06       0.00        77
# 4240            NNW       1015.0        29.97       0.00       0.00        44
# 5408              W       1017.0        30.03       0.41       0.02        59
#
#       cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 3265     50                16.0                   60.8           10.0
# 3460    100                16.0                   60.8           10.0
# 4045     25                18.0                   64.4           10.0
# 4240     25                13.7                   56.6           10.0
# 5408     75                15.2                   59.4           10.0
#
#       visibility_miles  uv_index  gust_mph  gust_kph  \
# 3265               6.0       4.0      22.5      36.3
# 3460               6.0       4.0      24.1      38.7
# 4045               6.0       4.0      20.6      33.1
# 4240               6.0       4.0      14.7      23.6
# 5408               6.0       3.0      17.5      28.2
#
#       air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 3265                        186.9               87.3
# 3460                        186.9               88.7
# 4045                        185.3               83.0
# 4240                        186.9               94.4
# 5408                        178.6               82.3
#
#       air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 3265                           2.7                          1.3
# 3460                           2.2                          1.8
# 4045                           5.1                          2.2
# 4240                           1.9                          1.4
# 5408                           1.4                          0.9
#
#       air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 3265                2.2               3.4                         1
# 3460                6.5              19.6                         1
# 4045                5.7               6.0                         1
# 4240                1.2               2.4                         1
# 5408                0.5               0.9                         1
#
#       air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 3265                           1  05:36 AM  09:52 PM  02:59 AM  02:09 PM
# 3460                           1  05:35 AM  09:53 PM  03:12 AM  03:34 PM
# 4045                           1  05:33 AM  09:56 PM  03:56 AM  07:57 PM
# 4240                           1  05:33 AM  09:56 PM  04:17 AM  09:25 PM
# 5408                           1  05:30 AM  10:01 PM  10:16 AM  01:31 AM
#
#            moon_phase  moon_illumination  temperature_fahrenheit_orig_f  Year  \
# 3265  Waning Crescent                 47                           60.8  2024
# 3460  Waning Crescent                 35                           60.8  2024
# 4045  Waning Crescent                  8                           64.4  2024
# 4240  Waning Crescent                  3                           59.0  2024
# 5408  Waxing Crescent                 21                           59.4  2024
#
#       Month  Day  Season temp_bin  temp_7d_mean  date_only year_month  year
# 3265      5   31  Spring    10-20     16.000000 2024-05-31    2024-05  2024
# 3460      6    1  Summer    10-20     16.000000 2024-06-01    2024-06  2024
# 4045      6    4  Summer    10-20     16.666667 2024-06-04    2024-06  2024
# 4240      6    5  Summer    10-20     16.250000 2024-06-05    2024-06  2024
# 5408      6   11  Summer    10-20     16.040000 2024-06-11    2024-06  2024
